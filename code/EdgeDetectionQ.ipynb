# %% [markdown]
# ## Edge Detection

# %%
import numpy as np
import cv2 
from matplotlib import pyplot as plt

# %% [markdown]
# ### Gradients
#
# #### Sobel
#
# #### Laplacian

# %%
img = cv2.imread('images/sudoku.png',0)
laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)  #  x방향 편미분, 수직성분 추출
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)  # y반향 편미분, 수평성분 추출

plt.figure(figsize=(10,8))
plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Canny Edge Detection

# %%
img = cv2.imread('images/lenna.bmp',0)
edges = cv2.Canny(img,80,240)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv2.imread('images/lenna-g.bmp')
kernel1 = np.full((3,3),-1, np.float32)   #3X3 8방향  Sharpening 마스크 생성
kernel1[1,1] = 9

imgB = cv2.GaussianBlur(img,(5,5),5) #sigma=5

dst1 = cv2.Canny(img,80,200)
dst2 = cv2.Canny(imgB, 80,200)

plt.figure(figsize=(10,8))
plt.subplot(221),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(222),plt.imshow(dst1,cmap = 'gray'),plt.title('Canny Edge ')
plt.xticks([]), plt.yticks([])
plt.subplot(223),plt.imshow(imgB),plt.title('Blur')
plt.xticks([]), plt.yticks([])
plt.subplot(224),plt.imshow(dst2,cmap = 'gray'),plt.title('Canny Edge ')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)  #  x방향 편미분, 수직성분 추출
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)  # y반향 편미분, 수평성분 추출

plt.figure(figsize=(10,8))
plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
laplacian = cv2.Laplacian(imgB,cv2.CV_64F)
sobelx = cv2.Sobel(imgB,cv2.CV_64F,1,0,ksize=5)  #  x방향 편미분, 수직성분 추출
sobely = cv2.Sobel(imgB,cv2.CV_64F,0,1,ksize=5)  # y반향 편미분, 수평성분 추출

plt.figure(figsize=(10,8))
plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
